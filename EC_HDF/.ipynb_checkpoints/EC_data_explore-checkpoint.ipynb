# %% [markdown]
# ### Install & load packages

# %%
options(stringsAsFactors=F, warn=-1)

devtools::install_github('NEONScience/NEON-utilities/neonUtilities', ref='eddy')
library(neonUtilities)
# Out:
# Skipping install of 'neonUtilities' from a github remote, the SHA1 (958412d2) has not changed since last install.
#   Use `force = TRUE` to force installation

# %% [markdown]
# Get some eddy flux data.

# %%
zipsByProduct(dpID="DP4.00200.001", package="basic", 
              site=c("NIWO", "HARV"), startdate="2018-06", enddate="2018-07",
              savepath="/Users/clunch/Desktop", check.size=F)
# Out:
# Downloading 4 files
#   |======================================================================| 100%
# 4 files downloaded to /Users/clunch/Desktop/filesToStack00200

# %% [markdown]
# Pull out the Level 4 data:

# %%
flux <- stackEC(filepath="/Users/clunch/Desktop/filesToStack00200/", level="dp04")
# Out:
# Extracting data
#   |======================================================================| 100%
# Stacking data tables by month
#   |======================================================================| 100%
# Joining data variables
#   |======================================================================| 100%

# %%
head(flux$NIWO)
# Out:
#   timeBgn                  timeEnd                  data.fluxCo2.nsae.flux
# 1 2018-06-01T00:00:00.000Z 2018-06-01T00:29:59.000Z 0.1111935
# 2 2018-06-01T00:30:00.000Z 2018-06-01T00:59:59.000Z 0.9328922
# 3 2018-06-01T01:00:00.000Z 2018-06-01T01:29:59.000Z 0.4673682
# 4 2018-06-01T01:30:00.000Z 2018-06-01T01:59:59.000Z 0.7263614
# 5 2018-06-01T02:00:00.000Z 2018-06-01T02:29:59.000Z 0.4740572
# 6 2018-06-01T02:30:00.000Z 2018-06-01T02:59:59.000Z 0.8807022
#   data.fluxCo2.stor.flux data.fluxCo2.turb.flux data.fluxH2o.nsae.flux
# 1 -0.06191186            0.1731053              19.401824
# 2  0.08534117            0.8475510              10.444936
# 3  0.02177216            0.4455960               5.140617
# 4  0.24944366            0.4769178               9.017467
# 5  0.22524363            0.2488136               3.180386
# 6  0.07078007            0.8099221               4.398761
#   data.fluxH2o.stor.flux data.fluxH2o.turb.flux data.fluxMome.turb.veloFric
# 1  3.2511265             16.150697              0.19707045
# 2 -1.1768333             11.621770              0.19699723
# 3 -4.3112673              9.451884              0.06518208
# 4  0.1980776              8.819389              0.12964000
# 5  0.1316297              3.048756              0.17460706
# 6 -0.2989443              4.697706              0.10477970
#   data.fluxTemp.nsae.flux ⋯ data.foot.stat.veloFric
# 1   4.1712006             ⋯ 0.2
# 2  -0.9163691             ⋯ 0.2
# 3  -2.9814957             ⋯ 0.2
# 4 -13.3556222             ⋯ 0.2
# 5  -5.3406503             ⋯ 0.2
# 6  -7.2739206             ⋯ 0.2
#   data.foot.stat.distZaxsMeasDisp data.foot.stat.distZaxsRgh
# 1 8.34                            0.03221479
# 2 8.34                            0.33007082
# 3 8.34                            0.12876068
# 4 8.34                            0.83400000
# 5 8.34                            0.83400000
# 6 8.34                            0.83400000
#   data.foot.stat.distZaxsAbl data.foot.stat.distXaxs90
# 1 1000                       333.60
# 2 1000                       258.54
# 3 1000                       308.58
# 4 1000                       208.50
# 5 1000                       208.50
# 6 1000                       208.50
#   data.foot.stat.distXaxsMax data.foot.stat.distYaxs90 qfqm.fluxCo2.stor.qfFinl
# 1 133.44                     25.02                     1
# 2 108.42                     50.04                     1
# 3 125.10                     58.38                     1
# 4  83.40                     75.06                     1
# 5  83.40                     66.72                     1
# 6  83.40                     41.70                     1
#   qfqm.fluxH2o.stor.qfFinl qfqm.fluxTemp.stor.qfFinl
# 1 1                        0
# 2 1                        0
# 3 1                        0
# 4 1                        0
# 5 1                        0
# 6 1                        0

# %% [markdown]
# Before we can plot anything, need to covert the time stamps to a recongnized date-time format. Let's work with the Niwot data.

# %%
timeBgn <- substring(flux$NIWO$timeBgn, 1, nchar(flux$NIWO$timeBgn)-4)
timeBgn <- strptime(timeBgn, format="%Y-%m-%dT%H:%M:%S")

timeEnd <- substring(flux$NIWO$timeEnd, 1, nchar(flux$NIWO$timeEnd)-4)
timeEnd <- strptime(timeEnd, format="%Y-%m-%dT%H:%M:%S")

timeBgn <- as.POSIXct(timeBgn)
timeEnd <- as.POSIXct(timeEnd)

# %%
plot(flux$NIWO$data.fluxCo2.nsae.flux~timeEnd, pch=".")
# Out:
# plot without title

# %%
plot(flux$NIWO$data.fluxCo2.nsae.flux~timeEnd, pch=".", ylim=c(-20,20))
# Out:
# plot without title

# %%
names(flux$NIWO)
# Out:
#  [1] "timeBgn"                         "timeEnd"
#  [3] "data.fluxCo2.nsae.flux"          "data.fluxCo2.stor.flux"
#  [5] "data.fluxCo2.turb.flux"          "data.fluxH2o.nsae.flux"
#  [7] "data.fluxH2o.stor.flux"          "data.fluxH2o.turb.flux"
#  [9] "data.fluxMome.turb.veloFric"     "data.fluxTemp.nsae.flux"
# [11] "data.fluxTemp.stor.flux"         "data.fluxTemp.turb.flux"
# [13] "data.foot.stat.angZaxsErth"      "data.foot.stat.distReso"
# [15] "data.foot.stat.veloYaxsHorSd"    "data.foot.stat.veloZaxsHorSd"
# [17] "data.foot.stat.veloFric"         "data.foot.stat.distZaxsMeasDisp"
# [19] "data.foot.stat.distZaxsRgh"      "data.foot.stat.distZaxsAbl"
# [21] "data.foot.stat.distXaxs90"       "data.foot.stat.distXaxsMax"
# [23] "data.foot.stat.distYaxs90"       "qfqm.fluxCo2.stor.qfFinl"
# [25] "qfqm.fluxH2o.stor.qfFinl"        "qfqm.fluxTemp.stor.qfFinl"

# %%
names(flux$HARV)
# Out:
#  [1] "timeBgn"                         "timeEnd"
#  [3] "data.fluxCo2.nsae.flux"          "data.fluxCo2.stor.flux"
#  [5] "data.fluxCo2.turb.flux"          "data.fluxH2o.nsae.flux"
#  [7] "data.fluxH2o.stor.flux"          "data.fluxH2o.turb.flux"
#  [9] "data.fluxMome.turb.veloFric"     "data.fluxTemp.nsae.flux"
# [11] "data.fluxTemp.stor.flux"         "data.fluxTemp.turb.flux"
# [13] "data.foot.stat.angZaxsErth"      "data.foot.stat.distReso"
# [15] "data.foot.stat.veloYaxsHorSd"    "data.foot.stat.veloZaxsHorSd"
# [17] "data.foot.stat.veloFric"         "data.foot.stat.distZaxsMeasDisp"
# [19] "data.foot.stat.distZaxsRgh"      "data.foot.stat.distZaxsAbl"
# [21] "data.foot.stat.distXaxs90"       "data.foot.stat.distXaxsMax"
# [23] "data.foot.stat.distYaxs90"       "qfqm.fluxCo2.stor.qfFinl"
# [25] "qfqm.fluxH2o.stor.qfFinl"        "qfqm.fluxTemp.stor.qfFinl"

# %%
plot(flux$NIWO$data.fluxCo2.nsae.flux[which(flux$NIWO$qfqm.fluxCo2.stor.qfFinl==0)]~
     timeEnd[which(flux$NIWO$qfqm.fluxCo2.stor.qfFinl==0)], pch=".", ylim=c(-20,20))
# Out:
# Error in plot.window(...): need finite 'xlim' values
# Traceback:
#
# 1. plot(flux$NIWO$data.fluxCo2.nsae.flux[which(flux$NIWO$qfqm.fluxCo2.stor.qfFinl ==
#  .     0)] ~ timeEnd[which(flux$NIWO$qfqm.fluxCo2.stor.qfFinl ==
#  .     0)], pch = ".", ylim = c(-20, 20))
# 2. plot.formula(flux$NIWO$data.fluxCo2.nsae.flux[which(flux$NIWO$qfqm.fluxCo2.stor.qfFinl ==
#  .     0)] ~ timeEnd[which(flux$NIWO$qfqm.fluxCo2.stor.qfFinl ==
#  .     0)], pch = ".", ylim = c(-20, 20))
# 3. do.call(funname, c(list(mf[[i]], y, ylab = yl, xlab = xl), dots))
# 4. plot(structure(numeric(0), class = c("POSIXct", "POSIXt"), tzone = ""),
#  .     numeric(0), ylab = "flux$NIWO$data.fluxCo2.nsae.flux[which(flux$NIWO$qfqm.fluxCo2.stor.qfFinl == 0)]",
#  .     xlab = "timeEnd[which(flux$NIWO$qfqm.fluxCo2.stor.qfFinl == 0)]",
#  .     pch = ".", ylim = c(-20, 20))
# 5. plot.default(structure(numeric(0), class = c("POSIXct", "POSIXt"
#  . ), tzone = ""), numeric(0), ylab = "flux$NIWO$data.fluxCo2.nsae.flux[which(flux$NIWO$qfqm.fluxCo2.stor.qfFinl == 0)]",
#  .     xlab = "timeEnd[which(flux$NIWO$qfqm.fluxCo2.stor.qfFinl == 0)]",
#  .     pch = ".", ylim = c(-20, 20))
# 6. localWindow(xlim, ylim, log, asp, ...)
# 7. plot.window(...)
# plot without title

# %%
min(flux$NIWO$qfqm.fluxCo2.stor.qfFinl)
max(flux$NIWO$qfqm.fluxCo2.stor.qfFinl)

min(flux$HARV$qfqm.fluxCo2.stor.qfFinl)
max(flux$HARV$qfqm.fluxCo2.stor.qfFinl)
# Out:
# [1] 1
# [1] 1
# [1] 0
# [1] 1

# %%
timeBgn <- substring(flux$HARV$timeBgn, 1, nchar(flux$HARV$timeBgn)-4)
timeBgn <- strptime(timeBgn, format="%Y-%m-%dT%H:%M:%S")

timeEnd <- substring(flux$HARV$timeEnd, 1, nchar(flux$HARV$timeEnd)-4)
timeEnd <- strptime(timeEnd, format="%Y-%m-%dT%H:%M:%S")

timeBgn <- as.POSIXct(timeBgn)
timeEnd <- as.POSIXct(timeEnd)

plot(flux$HARV$data.fluxCo2.nsae.flux[which(flux$HARV$qfqm.fluxCo2.stor.qfFinl==0)]~
     timeEnd[which(flux$HARV$qfqm.fluxCo2.stor.qfFinl==0)], pch=".", ylim=c(-20,20))
# Out:
# plot without title

# %% [markdown]
# Let's bring together with some other IS data

# %%
pr <- loadByProduct("DP1.00024.001", package="basic", check.size=F,
                   site="NIWO", startdate="2018-06", enddate="2018-07")
# Out:
# Downloading 2 files
#   |======================================================================| 100%
#
# Unpacking zip files
#   |======================================================================| 100%
# Stacking table PARPAR_1min
#   |======================================================================| 100%
# Stacking table PARPAR_30min
#   |======================================================================| 100%
# Finished: All of the data are stacked into 2 tables!
# Copied the first available variable definition file to /stackedFiles and renamed as variables.csv
# Stacked PARPAR_1min which has 351360 out of the expected 351360 rows (100%).
# Stacked PARPAR_30min which has 11712 out of the expected 11712 rows (100%).
# Stacking took 6.817735 secs
# All unzipped monthly data folders have been removed.

# %%
head(pr$PARPAR_30min)
# Out:
#   domainID siteID horizontalPosition verticalPosition startDateTime
# 1 D13      NIWO   0                  10               2018-06-01T00:00:00Z
# 2 D13      NIWO   0                  10               2018-06-01T00:30:00Z
# 3 D13      NIWO   0                  10               2018-06-01T01:00:00Z
# 4 D13      NIWO   0                  10               2018-06-01T01:30:00Z
# 5 D13      NIWO   0                  10               2018-06-01T02:00:00Z
# 6 D13      NIWO   0                  10               2018-06-01T02:30:00Z
#   endDateTime          PARMean PARMinimum PARMaximum PARVariance ⋯ PARStdErMean
# 1 2018-06-01T00:30:00Z 314.01  135.68     799.44     17114.85    ⋯ 3.08
# 2 2018-06-01T01:00:00Z  94.04   45.38     176.53      1700.74    ⋯ 0.97
# 3 2018-06-01T01:30:00Z 140.92   82.84     174.21       601.27    ⋯ 0.58
# 4 2018-06-01T02:00:00Z  38.40   14.69      82.89       388.65    ⋯ 0.46
# 5 2018-06-01T02:30:00Z   8.39    3.16      14.92         9.44    ⋯ 0.07
# 6 2018-06-01T03:00:00Z   0.85   -0.08       3.28         0.80    ⋯ 0.02
#   PARFinalQF outPARMean outPARMinimum outPARMaximum outPARVariance outPARNumPts
# 1 0          NA         NA            NA            NA             NA
# 2 0          NA         NA            NA            NA             NA
# 3 0          NA         NA            NA            NA             NA
# 4 0          NA         NA            NA            NA             NA
# 5 0          NA         NA            NA            NA             NA
# 6 0          NA         NA            NA            NA             NA
#   outPARExpUncert outPARStdErMean outPARFinalQF
# 1 NA              NA              NA
# 2 NA              NA              NA
# 3 NA              NA              NA
# 4 NA              NA              NA
# 5 NA              NA              NA
# 6 NA              NA              NA

# %%
pr.top <- pr$PARPAR_30min[which(pr$PARPAR_30min$verticalPosition==max(pr$PARPAR_30min$verticalPosition)),]
endDT <- strptime(pr.top$endDateTime, format="%Y-%m-%dT%H:%M:%SZ")
endDT <- as.POSIXct(endDT)

# %%
pr.top <- cbind(endDT, pr.top)

tEnd <- timeEnd
flux$NIWO <- cbind(tEnd, flux$NIWO)

# %%
fx.pr <- merge(pr.top, flux$NIWO, by.x='endDateTime', by.y="tEnd")

# %%
head(pr.top)
head(flux$NIWO)
# Out:
#      endDT               domainID siteID horizontalPosition verticalPosition
# 4321 2018-06-01 00:30:00 D13      NIWO   0                  40
# 4322 2018-06-01 01:00:00 D13      NIWO   0                  40
# 4323 2018-06-01 01:30:00 D13      NIWO   0                  40
# 4324 2018-06-01 02:00:00 D13      NIWO   0                  40
# 4325 2018-06-01 02:30:00 D13      NIWO   0                  40
# 4326 2018-06-01 03:00:00 D13      NIWO   0                  40
#      startDateTime        endDateTime PARMean PARMinimum PARMaximum ⋯
# 4321 2018-06-01T00:00:00Z <NA>        314.10  131.73     795.80     ⋯
# 4322 2018-06-01T00:30:00Z <NA>         94.55   45.34     179.59     ⋯
# 4323 2018-06-01T01:00:00Z <NA>        144.89   85.21     178.24     ⋯
# 4324 2018-06-01T01:30:00Z <NA>         39.29   15.30      85.10     ⋯
# 4325 2018-06-01T02:00:00Z <NA>          9.25    3.88      15.42     ⋯
# 4326 2018-06-01T02:30:00Z <NA>          1.92    0.55       4.62     ⋯
#      PARStdErMean PARFinalQF outPARMean outPARMinimum outPARMaximum
# 4321 3.09         0          33.19      13.39         103.55
# 4322 0.97         0           9.39       4.50          18.68
# 4323 0.58         0          14.31       7.96          19.44
# 4324 0.48         0           3.57       1.14           8.21
# 4325 0.07         0           0.62      -0.58           1.37
# 4326 0.02         0          -0.15      -0.89           1.47
#      outPARVariance outPARNumPts outPARExpUncert outPARStdErMean outPARFinalQF
# 4321 330.67         1800         3.32            0.43            0
# 4322  17.47         1800         0.62            0.10            0
# 4323   6.48         1800         0.62            0.06            0
# 4324   3.75         1800         0.28            0.05            0
# 4325   0.11         1800         0.08            0.01            0
# 4326   0.03         1800         0.08            0.00            0
#   tEnd                tEnd.1              timeBgn
# 1 2018-06-01 00:29:59 2018-06-01 00:29:59 2018-06-01T00:00:00.000Z
# 2 2018-06-01 00:59:59 2018-06-01 00:59:59 2018-06-01T00:30:00.000Z
# 3 2018-06-01 01:29:59 2018-06-01 01:29:59 2018-06-01T01:00:00.000Z
# 4 2018-06-01 01:59:59 2018-06-01 01:59:59 2018-06-01T01:30:00.000Z
# 5 2018-06-01 02:29:59 2018-06-01 02:29:59 2018-06-01T02:00:00.000Z
# 6 2018-06-01 02:59:59 2018-06-01 02:59:59 2018-06-01T02:30:00.000Z
#   timeEnd                  data.fluxCo2.nsae.flux data.fluxCo2.stor.flux
# 1 2018-06-01T00:29:59.000Z 0.1111935              -0.06191186
# 2 2018-06-01T00:59:59.000Z 0.9328922               0.08534117
# 3 2018-06-01T01:29:59.000Z 0.4673682               0.02177216
# 4 2018-06-01T01:59:59.000Z 0.7263614               0.24944366
# 5 2018-06-01T02:29:59.000Z 0.4740572               0.22524363
# 6 2018-06-01T02:59:59.000Z 0.8807022               0.07078007
#   data.fluxCo2.turb.flux data.fluxH2o.nsae.flux data.fluxH2o.stor.flux
# 1 0.1731053              19.401824               3.2511265
# 2 0.8475510              10.444936              -1.1768333
# 3 0.4455960               5.140617              -4.3112673
# 4 0.4769178               9.017467               0.1980776
# 5 0.2488136               3.180386               0.1316297
# 6 0.8099221               4.398761              -0.2989443
#   data.fluxH2o.turb.flux ⋯ data.foot.stat.veloFric
# 1 16.150697              ⋯ 0.2
# 2 11.621770              ⋯ 0.2
# 3  9.451884              ⋯ 0.2
# 4  8.819389              ⋯ 0.2
# 5  3.048756              ⋯ 0.2
# 6  4.697706              ⋯ 0.2
#   data.foot.stat.distZaxsMeasDisp data.foot.stat.distZaxsRgh
# 1 8.34                            0.03221479
# 2 8.34                            0.33007082
# 3 8.34                            0.12876068
# 4 8.34                            0.83400000
# 5 8.34                            0.83400000
# 6 8.34                            0.83400000
#   data.foot.stat.distZaxsAbl data.foot.stat.distXaxs90
# 1 1000                       333.60
# 2 1000                       258.54
# 3 1000                       308.58
# 4 1000                       208.50
# 5 1000                       208.50
# 6 1000                       208.50
#   data.foot.stat.distXaxsMax data.foot.stat.distYaxs90 qfqm.fluxCo2.stor.qfFinl
# 1 133.44                     25.02                     1
# 2 108.42                     50.04                     1
# 3 125.10                     58.38                     1
# 4  83.40                     75.06                     1
# 5  83.40                     66.72                     1
# 6  83.40                     41.70                     1
#   qfqm.fluxH2o.stor.qfFinl qfqm.fluxTemp.stor.qfFinl
# 1 1                        0
# 2 1                        0
# 3 1                        0
# 4 1                        0
# 5 1                        0
# 6 1                        0

# %%
plot(fx.pr$data.fluxCo2.nsae.flux~fx.pr$PARMean, pch=".")
# Out:
# Error in plot.window(...): need finite 'xlim' values
# Traceback:
#
# 1. plot(fx.pr$data.fluxCo2.nsae.flux ~ fx.pr$PARMean, pch = ".")
# 2. plot.formula(fx.pr$data.fluxCo2.nsae.flux ~ fx.pr$PARMean, pch = ".")
# 3. do.call(funname, c(list(mf[[i]], y, ylab = yl, xlab = xl), dots))
# 4. plot(numeric(0), numeric(0), ylab = "fx.pr$data.fluxCo2.nsae.flux",
#  .     xlab = "fx.pr$PARMean", pch = ".")
# 5. plot.default(numeric(0), numeric(0), ylab = "fx.pr$data.fluxCo2.nsae.flux",
#  .     xlab = "fx.pr$PARMean", pch = ".")
# 6. localWindow(xlim, ylim, log, asp, ...)
# 7. plot.window(...)
# plot without title
