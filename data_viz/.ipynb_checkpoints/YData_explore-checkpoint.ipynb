# %%
import numpy as np
import pandas as pd
import neonutilities as nu
from ydata_profiling import ProfileReport
# Out:
# Pandas backend loaded 2.2.0
# Numpy backend loaded 1.26.0
# Pyspark backend NOT loaded
# Python backend loaded

# %%
bird = nu.load_by_product('DP1.10003.001', site='WREF', startdate='2022-01', include_provisional=True, check_size=False, progress=False)

# %%
birdct = bird['brd_countdata']

# %%
profile = ProfileReport(birdct, title="WREF Bird Profiling Report")

# %%
profile.to_notebook_iframe()
# Out:
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-02-18 17:58:46.819022&quot;&gt;&lt;title&gt;WREF Bird Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
