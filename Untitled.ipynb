# %%
import neonutilities as nu

# %%
nu.zips_by_product(dpid="DP4.00200.001",
                   site="ORNL",
                   startdate="2023-10",
                   enddate="2024-09",
                   release="RELEASE-2026",
                   package="basic",
                   check_size=False,
                  savepath='/Users/clunch/Desktop')
# Out:
# Finding available files
# ...
# 100%|███████████████████████████████████████████| 12/12 [01:02<00:00,  5.25s/it]

# %%
sae_py = nu.stack_eddy(filepath = "/Users/clunch/Desktop/filesToStack00200")
# Out:
# ...
# Stacking files by month: 100%|███████████████████| 1/1 [00:00<00:00, 467.07it/s]

# %%
sae_py["ORNL"].head()
# Out:
#                     timeBgn                   timeEnd  data.fluxCo2.nsae.flux  \
# 0 2023-10-01 00:00:00+00:00 2023-10-01 00:29:59+00:00                2.388101
# 1 2023-10-01 00:30:00+00:00 2023-10-01 00:59:59+00:00                2.388159
# 2 2023-10-01 01:00:00+00:00 2023-10-01 01:29:59+00:00                3.152132
# 3 2023-10-01 01:30:00+00:00 2023-10-01 01:59:59+00:00                5.944850
# 4 2023-10-01 02:00:00+00:00 2023-10-01 02:29:59+00:00               -0.973948
#
#    data.fluxCo2.stor.flux  data.fluxCo2.turb.flux  data.fluxH2o.nsae.flux  \
# 0               -0.517725                2.905826               17.823223
# 1               -0.115772                2.503931               20.157573
# 2                0.532634                2.619497               24.418599
# 3                4.718231                1.226620               23.649364
# 4               -1.099887                0.125939               12.710899
#
# ...

# %%
sae_py.keys()
# Out:
# dict_keys(['ORNL', 'variables', 'objDesc', 'issueLog', 'citation_00200_RELEASE-2026'])
