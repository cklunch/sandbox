# %%
import pandas

# %%
import datetime as d

# %%
data = pandas.read_csv("/Users/clunch/Desktop/cfc_fieldData_herb.csv")

# %%
data.head()
# Out:
#                                     uid          namedLocation domainID  \
# 0  96de6074-bf30-4052-afc0-89596f16c1b2  SCBI_006.basePlot.cfc      D02
# 1  e7c9e828-9fdc-4d27-b021-fc3dcc79b821  SCBI_005.basePlot.cfc      D02
# 2  ea958b71-aa8c-48c9-8977-6bc9526eadde  SERC_008.basePlot.cfc      D02
# 3  8321ef8d-0d5d-4676-80f7-d4991d8d3525  SERC_007.basePlot.cfc      D02
# 4  529c3c5a-5779-438e-bf5f-fe6d4938179d  SERC_003.basePlot.cfc      D02
#
#   siteID    plotID     plotType        nlcdClass geodeticDatum  \
# 0   SCBI  SCBI_006  distributed       pastureHay         WGS84
# 1   SCBI  SCBI_005  distributed  deciduousForest         WGS84
# 2   SERC  SERC_008  distributed  cultivatedCrops         WGS84
# 3   SERC  SERC_007  distributed  cultivatedCrops         WGS84
# 4   SERC  SERC_003  distributed  deciduousForest         WGS84
#
#    decimalLatitude  decimalLongitude    ...      subsample1Height  \
# 0        38.897609        -78.152007    ...                   NaN
# ...

# %%
data.dtypes
# Out:
# uid                         object
# namedLocation               object
# domainID                    object
# siteID                      object
# plotID                      object
# plotType                    object
# nlcdClass                   object
# geodeticDatum               object
# decimalLatitude            float64
# decimalLongitude           float64
# coordinateUncertainty      float64
# elevation                  float64
# elevationUncertainty       float64
# samplingProtocolVersion     object
# collectDate                 object
# subplotID                    int64
# sampleType                  object
# samplingMethod              object
# vstTag                     float64
# tagID                      float64
# individualID               float64
# taxonID                    float64
# scientificName             float64
# plantStatus                 object
# clipCellNumber               int64
# clipID                      object
# clipLength                 float64
# ...

# %%
collectDate_dt = pandas.to_datetime(data.collectDate, format='%Y-%m-%dT%H:%MZ')

# %%
collectDate_dt.head()
# Out:
# 0   2017-08-03 13:00:00
# 1   2017-08-03 19:00:00
# 2   2016-07-27 11:14:00
# 3   2016-07-27 12:00:00
# 4   2016-07-27 13:40:00
# Name: collectDate, dtype: datetime64[ns]

# %%
ql = pandas.read_csv("/Users/clunch/Desktop/NEON_par-quantum-line/stackedFiles/PARQL_30min.csv")

# %%
ql.head()
# Out:
#   domainID siteID  horizontalPosition  verticalPosition         startDateTime  \
# 0      D04   GUAN                   1                 0  2017-01-21T00:00:00Z
# 1      D04   GUAN                   1                 0  2017-01-21T00:30:00Z
# 2      D04   GUAN                   1                 0  2017-01-21T01:00:00Z
# 3      D04   GUAN                   1                 0  2017-01-21T01:30:00Z
# 4      D04   GUAN                   1                 0  2017-01-21T02:00:00Z
#
#             endDateTime  linePARMean  linePARMinimum  linePARMaximum  \
# 0  2017-01-21T00:30:00Z          NaN             NaN             NaN
# 1  2017-01-21T01:00:00Z          NaN             NaN             NaN
# 2  2017-01-21T01:30:00Z          NaN             NaN             NaN
# 3  2017-01-21T02:00:00Z          NaN             NaN             NaN
# 4  2017-01-21T02:30:00Z          NaN             NaN             NaN
#
#    linePARVariance  linePARNumPts  linePARSkewness  linePARKurtosis  \
# ...

# %%
ql.endDateTime = pandas.to_datetime(ql.endDateTime, format='%Y-%m-%dT%H:%M:%SZ')

# %%
ql.head()
# Out:
#   domainID siteID  horizontalPosition  verticalPosition         startDateTime  \
# 0      D04   GUAN                   1                 0  2017-01-21T00:00:00Z
# 1      D04   GUAN                   1                 0  2017-01-21T00:30:00Z
# 2      D04   GUAN                   1                 0  2017-01-21T01:00:00Z
# 3      D04   GUAN                   1                 0  2017-01-21T01:30:00Z
# 4      D04   GUAN                   1                 0  2017-01-21T02:00:00Z
#
#           endDateTime  linePARMean  linePARMinimum  linePARMaximum  \
# 0 2017-01-21 00:30:00          NaN             NaN             NaN
# 1 2017-01-21 01:00:00          NaN             NaN             NaN
# 2 2017-01-21 01:30:00          NaN             NaN             NaN
# 3 2017-01-21 02:00:00          NaN             NaN             NaN
# 4 2017-01-21 02:30:00          NaN             NaN             NaN
#
#    linePARVariance  linePARNumPts  linePARSkewness  linePARKurtosis  \
# ...
